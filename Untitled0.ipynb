# %% [markdown]
# <a href="https://colab.research.google.com/github/klaraisy/phage-annotation/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/gbouras13/phold.git
# Out:
# Cloning into 'phold'...
# remote: Enumerating objects: 2316, done.
# remote: Counting objects: 100% (708/708), done.
# remote: Compressing objects: 100% (386/386), done.
# remote: Total 2316 (delta 351), reused 433 (delta 271), pack-reused 1608 (from 1)
# Receiving objects: 100% (2316/2316), 57.40 MiB | 31.65 MiB/s, done.
# Resolving deltas: 100% (1297/1297), done.

# %%
# !pip install biopython numpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 44.6 MB/s eta 0:00:00
# ...

# %%
# !find /content/phold/src -name '*.py'
# Out:
# /content/phold/src/phold/plot/plot.py
# /content/phold/src/phold/__init__.py
# /content/phold/src/phold/subcommands/compare.py
# /content/phold/src/phold/subcommands/predict.py
# /content/phold/src/phold/features/query_remote_3Di.py
# /content/phold/src/phold/features/eat.py
# /content/phold/src/phold/features/split_3Di.py
# /content/phold/src/phold/features/create_foldseek_db.py
# /content/phold/src/phold/features/run_foldseek.py
# /content/phold/src/phold/features/predict_3Di_finetune.py
# /content/phold/src/phold/features/predict_3Di.py
# /content/phold/src/phold/results/topfunction.py
# /content/phold/src/phold/databases/db.py
# /content/phold/src/phold/utils/external_tools.py
# /content/phold/src/phold/utils/util.py
# /content/phold/src/phold/utils/validation.py
# /content/phold/src/phold/utils/constants.py
# /content/phold/src/phold/io/sub_db_outputs.py
# /content/phold/src/phold/io/handle_genbank.py

# %%
# !find /content/phold/phold -name '*.py'
# Out:
# find: ‘/content/phold/phold’: No such file or directory

# %%
# !pip install -e /content/phold/phold
# Out:
# ERROR: /content/phold/phold is not a valid editable requirement. It should either be a path to a local project or a VCS URL (beginning with bzr+http, bzr+https, bzr+ssh, bzr+sftp, bzr+ftp, bzr+lp, bzr+file, git+http, git+https, git+ssh, git+git, git+file, hg+file, hg+http, hg+https, hg+ssh, hg+static-http, svn+ssh, svn+http, svn+https, svn+svn, svn+file).

# %%
# %cd /content/phold
# !pip install -e .
# Out:
# /content/phold
# Obtaining file:///content/phold
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.7/72.7 kB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.4/56.4 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 68.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.6/77.6 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.9/849.9 kB 31.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
# ...

# %%
# !phold run -i 5131.fasta -f

# %%
# Install phold
# !pip install phold

# %%
# 1. Install phold Python package
# !pip install phold

# 2. Download and extract Foldseek precompiled Linux binaries
# !wget -q https://github.com/steineggerlab/foldseek/releases/download/v4.4.0/foldseek-linux.tar.gz
# !tar -xzf foldseek-linux.tar.gz

# 3. Add Foldseek binary folder to PATH for this session
import os
os.environ['PATH'] += ":/content/foldseek-linux"

# 4. Verify foldseek is accessible
# !which foldseek
# Out:
# ...
# tar (child): foldseek-linux.tar.gz: Cannot open: No such file or directory
# tar (child): Error is not recoverable: exiting now
# tar: Child returned status 2
# tar: Error is not recoverable: exiting now

# %%
# Download the AVX2 precompiled binary
# !wget https://mmseqs.com/foldseek/foldseek-linux-avx2.tar.gz

# Extract the downloaded archive
# !tar -xzf foldseek-linux-avx2.tar.gz
# Out:
# --2025-08-04 12:42:48--  https://mmseqs.com/foldseek/foldseek-linux-avx2.tar.gz
# Resolving mmseqs.com (mmseqs.com)... 158.247.200.62
# Connecting to mmseqs.com (mmseqs.com)|158.247.200.62|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11431210 (11M) [application/octet-stream]
# Saving to: ‘foldseek-linux-avx2.tar.gz’
#
# foldseek-linux-avx2 100%[===================>]  10.90M  7.35MB/s    in 1.5s
#
# 2025-08-04 12:42:51 (7.35 MB/s) - ‘foldseek-linux-avx2.tar.gz’ saved [11431210/11431210]

# %%
# !export PATH=$PATH:/content/foldseek/bin && which foldseek && foldseek --help
import os
os.environ['PATH'] += ":/content/foldseek/bin"
# Out:
# /content/foldseek/bin/foldseek
# Foldseek enables fast and sensitive comparisons of large structure sets. It reaches sensitivities similar to state-of-the-art structural aligners while being at least 20,000 times faster.
#
# Please cite:
# van Kempen, M., Kim, S.S., Tumescheit, C., Mirdita, M., Lee, J., Gilchrist, C.L.M., Söding, J., and Steinegger, M. Fast and accurate protein structure search with Foldseek. Nature Biotechnology, doi:10.1038/s41587-023-01773-0 (2023)
#
# foldseek Version: cfb431e98abcc5bcc49950285211d3723b47dc94
# © Michel van Kempen, Stephanie Kim, Charlotte Tumescheit, Milot Mirdita, Jeongjae Lee, Cameron L. M. Gilchrist, Johannes Söding, Martin Steinegger
#
# usage: foldseek <command> [<args>]
#
# Easy workflows for plain text input/output
#   easy-search       	Structual search
#   easy-cluster      	Slower, sensitive clustering
#   easy-rbh          	Find reciprocal best hit
#   easy-multimercluster	Multimer level cluster
# ...

# %%
# 1. Install Phold
# !pip install phold

# 2. Download and extract Foldseek AVX2 binary
# !wget -q https://mmseqs.com/foldseek/foldseek-linux-avx2.tar.gz
# !tar -xzf foldseek-linux-avx2.tar.gz

# 3. Add Foldseek to PATH for this session
import os
os.environ['PATH'] += ":/content/foldseek/bin"

# 4. Download and install the Phold database
# !phold install

# 5. Run Phold prediction on your file (assuming 5131.fasta is uploaded)
# !export PATH=$PATH:/content/foldseek/bin && phold predict --input 5131.fasta --output phold_output

# 6. Zip the output folder for download
# !zip -r phold_output.zip phold_output

# 7. Provide download link
from google.colab import files
files.download("phold_output.zip")
# Out:
# ...
# 2025-08-04 12:48:28.795231: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754311708.820180    4662 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754311708.827684    4662 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-08-04 12:48:28.851802: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# 1. Install Phold
# !pip install phold

# 2. Download and extract Foldseek AVX2 binary
# !wget -q https://mmseqs.com/foldseek/foldseek-linux-avx2.tar.gz
# !tar -xzf foldseek-linux-avx2.tar.gz

# 3. Add Foldseek to PATH
import os
os.environ['PATH'] += ":/content/foldseek/bin"

# 4. Install the Phold database
# !phold install

# 5. Run Phold prediction with overwrite
# !export PATH=$PATH:/content/foldseek/bin && phold predict --input 5131.fasta --output phold_output --force

# 6. Zip and download results
# !zip -r phold_output.zip phold_output

from google.colab import files
files.download("phold_output.zip")
# Out:
# ...
# 2025-08-04 13:48:28.922449: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754315308.943451    6623 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754315308.949778    6623 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-08-04 13:48:28.970318: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# 1. Install Phold
# !pip install phold

# 2. Download and extract Foldseek AVX2 binary
# !wget -q https://mmseqs.com/foldseek/foldseek-linux-avx2.tar.gz
# !tar -xzf foldseek-linux-avx2.tar.gz

# 3. Add Foldseek to PATH
import os
os.environ['PATH'] += ":/content/foldseek/bin"

# 4. Install the Phold database
# !phold install

# 5. Run Phold prediction with overwrite
# !export PATH=$PATH:/content/foldseek/bin && phold predict --input 5131.fasta --output phold_output --force

# 6. Zip and download results
# !zip -r phold_output.zip phold_output

from google.colab import files
files.download("phold_output.zip")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.7/72.7 kB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.4/56.4 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 14.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 8.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 110.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.6/77.6 kB 8.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.9/849.9 kB 60.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 123.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 92.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 61.8 MB/s eta 0:00:00
# ...
